# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('healthcare_dataset.csv')
df
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# ...

# %%
df.isnull().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %%
df.shape
# Out:
# (55500, 15)

# %%
df.head()
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %%
df = df[['Hospital','Date of Admission','Discharge Date','Name','Age','Gender','Blood Type','Medical Condition','Doctor','Insurance Provider','Billing Amount','Room Number','Admission Type','Medication','Test Results']]
df.head()
# Out:
#                      Hospital Date of Admission Discharge Date           Name  \
# 0             Sons and Miller        2024-01-31     2024-02-02  Bobby JacksOn
# 1                     Kim Inc        2019-08-20     2019-08-26   LesLie TErRy
# 2                    Cook PLC        2022-09-22     2022-10-07    DaNnY sMitH
# 3  Hernandez Rogers and Vang,        2020-11-18     2020-12-18   andrEw waTtS
# 4                 White-White        2022-09-19     2022-10-09  adrIENNE bEll
#
#    Age  Gender Blood Type Medical Condition            Doctor  \
# 0   30    Male         B-            Cancer     Matthew Smith
# 1   62    Male         A+           Obesity   Samantha Davies
# 2   76  Female         A-           Obesity  Tiffany Mitchell
# 3   28  Female         O+          Diabetes       Kevin Wells
# 4   43  Female        AB+            Cancer    Kathleen Hanna
#
#   Insurance Provider  Billing Amount  Room Number Admission Type   Medication  \
# ...

# %%
df.shape
# Out:
# (55500, 15)

# %%
df1 = df.sort_values(by = 'Hospital', ascending = True)
df1.head()
# Out:
#                             Hospital Date of Admission Discharge Date  \
# 49809                     Abbott Inc        2022-05-07     2022-05-10
# 31744                     Abbott Ltd        2022-08-01     2022-08-20
# 14349     Abbott Moore and Williams,        2022-08-25     2022-09-19
# 26141  Abbott and Thompson, Sullivan        2022-12-03     2022-12-29
# 50375     Abbott, Peters and Hoffman        2022-01-05     2022-01-18
#
#                  Name  Age  Gender Blood Type Medical Condition  \
# 49809  RONaLD HuBBard   59  Female         O+         Arthritis
# 31744   hEATHEr SMITh   59    Male         O-         Arthritis
# 14349   KiMBerly caRr   39    Male        AB+           Obesity
# 26141      lAURa tAte   84    Male         B-      Hypertension
# 50375    samUEL GomEZ   62    Male         A-          Diabetes
#
#                  Doctor Insurance Provider  Billing Amount  Room Number  \
# 49809      Brandi Lucas           Medicare    38052.041917          467
# ...

# %%
df1.shape
# Out:
# (55500, 15)

# %%
df1['Name'] = df1.Name.str.title()
df1.head()
# Out:
#                             Hospital Date of Admission Discharge Date  \
# 49809                     Abbott Inc        2022-05-07     2022-05-10
# 31744                     Abbott Ltd        2022-08-01     2022-08-20
# 14349     Abbott Moore and Williams,        2022-08-25     2022-09-19
# 26141  Abbott and Thompson, Sullivan        2022-12-03     2022-12-29
# 50375     Abbott, Peters and Hoffman        2022-01-05     2022-01-18
#
#                  Name  Age  Gender Blood Type Medical Condition  \
# 49809  Ronald Hubbard   59  Female         O+         Arthritis
# 31744   Heather Smith   59    Male         O-         Arthritis
# 14349   Kimberly Carr   39    Male        AB+           Obesity
# 26141      Laura Tate   84    Male         B-      Hypertension
# 50375    Samuel Gomez   62    Male         A-          Diabetes
#
#                  Doctor Insurance Provider  Billing Amount  Room Number  \
# 49809      Brandi Lucas           Medicare    38052.041917          467
# ...

# %%
col_to_move = 'Name'  # Specify the column to move
new_position = 1  # Desired position

cols = [col for col in df1.columns if col != col_to_move]
cols.insert(new_position, col_to_move)
df2 = df1[cols]
df2
# Out:
#                             Hospital            Name Date of Admission  \
# 49809                     Abbott Inc  Ronald Hubbard        2022-05-07
# 31744                     Abbott Ltd   Heather Smith        2022-08-01
# 14349     Abbott Moore and Williams,   Kimberly Carr        2022-08-25
# 26141  Abbott and Thompson, Sullivan      Laura Tate        2022-12-03
# 50375     Abbott, Peters and Hoffman    Samuel Gomez        2022-01-05
# ...                              ...             ...               ...
# 3657              and Zimmerman Sons   Trevor Conway        2019-08-14
# 47416      and Zuniga Davis Carlson,   Matthew Barry        2019-10-25
# 24525   and Zuniga Francis Peterson,  Cindy Mcdaniel        2020-09-03
# 14567                and Zuniga Sons     Barry Barry        2022-07-15
# 3582      and Zuniga Thompson, Blake     Rita Parker        2022-06-24
#
#       Discharge Date  Age  Gender Blood Type Medical Condition  \
# ...

# %%
df2 = df2.sort_values(by = 'Age', ascending = True)
df2
# Out:
#                               Hospital               Name Date of Admission  \
# 51900            and Huerta, Cox Price     Jacob Williams        2020-03-03
# 50908        Kelly, and Gomez Williams       Ronald Davis        2023-12-06
# 50377        Pollard Wallace, Sims and     James Bass Phd        2020-12-30
# 53590                   Davis-Lawrence      Jessica Chung        2020-07-06
# 52172  Arellano and Armstrong Hensley,     Charles Jordan        2021-05-13
# ...                                ...                ...               ...
# 53825      and Perez, Bennett Townsend      Michael Potts        2023-01-19
# 54044                        PLC White  Michael Dominguez        2021-09-07
# 54813                     Gray-Solomon  Jeremy Hardin Jr.        2019-11-05
# 52372          and Miller, Olson Olson    Deborah Mcbride        2021-05-28
# 52828        Holmes and Howard Castro,       Donald Avila        2022-09-17
#
# ...

# %%
col = ['Age','Gender','Blood Type','Medical Condition','Admission Type']
grouped = df2.groupby(col,as_index =True)['Age']
result = grouped.count()
result.head()
# Out:
# Age  Gender  Blood Type  Medical Condition  Admission Type
# 13   Female  A+          Obesity            Urgent            1
#              AB+         Arthritis          Emergency         1
#              B-          Asthma             Emergency         1
#                          Obesity            Urgent            1
#              O-          Cancer             Elective          1
# Name: Age, dtype: int64

# %%
a = result.Age.isin([13])
b = result[a]
b
# Out:
# Empty DataFrame
# Columns: [Gender, Blood Type, Medical Condition, Admission Type, Age]
# Index: []

# %%
df2.head()
# Out:
#                               Hospital            Name Date of Admission  \
# 51900            and Huerta, Cox Price  Jacob Williams        2020-03-03
# 50908        Kelly, and Gomez Williams    Ronald Davis        2023-12-06
# 50377        Pollard Wallace, Sims and  James Bass Phd        2020-12-30
# 53590                   Davis-Lawrence   Jessica Chung        2020-07-06
# 52172  Arellano and Armstrong Hensley,  Charles Jordan        2021-05-13
#
#       Discharge Date  Age  Gender Blood Type Medical Condition  \
# 51900     2020-03-20   13  Female         A+           Obesity
# 50908     2024-01-04   13    Male         A+           Obesity
# 50377     2021-01-17   13    Male         O+            Asthma
# 53590     2020-07-11   13    Male        AB+           Obesity
# 52172     2021-06-12   13    Male         A+         Arthritis
#
#                  Doctor Insurance Provider  Billing Amount  Room Number  \
# ...

# %%
cure = df2['Medical Condition'] == 'Obesity'
Cure = df2[cure]
Cure
# Out:
#                           Hospital               Name Date of Admission  \
# 51900        and Huerta, Cox Price     Jacob Williams        2020-03-03
# 50908    Kelly, and Gomez Williams       Ronald Davis        2023-12-06
# 53590               Davis-Lawrence      Jessica Chung        2020-07-06
# 51095                 Wood-Johnson       Cathy Barnes        2023-03-30
# 50823  and Sanchez Phillips, Brown      Deanna Palmer        2020-09-20
# ...                            ...                ...               ...
# 50780       Perez, Benton West and       Bethany Wood        2021-11-22
# 51708                  Byrd-Porter   Crystal Martinez        2021-11-10
# 54800      Wood and Barnett Smith,  Jennifer Gonzalez        2023-09-13
# 54670     and Gray Smith, Jennings         Jade Baker        2021-05-31
# 52372      and Miller, Olson Olson    Deborah Mcbride        2021-05-28
#
#       Discharge Date  Age  Gender Blood Type Medical Condition  \
# ...

# %%
a = Cure.Gender.value_counts()
a
# Out:
# Gender
# Female    4622
# Male      4609
# Name: count, dtype: int64

# %%
cols = ['Age','Gender']
grouped = Cure.groupby(cols, as_index = False)['Age']
result = grouped.size()
result
# Out:
#      Age  Gender  size
# 0     13  Female     2
# 1     13    Male     4
# 2     14  Female     4
# 3     14    Male     2
# 4     15  Female     3
# ..   ...     ...   ...
# 147   86    Male     1
# 148   87  Female     2
# 149   87    Male     4
# 150   88  Female     2
# 151   89  Female     1
#
# [152 rows x 3 columns]

# %%
df2.head()
# Out:
#                               Hospital            Name Date of Admission  \
# 51900            and Huerta, Cox Price  Jacob Williams        2020-03-03
# 50908        Kelly, and Gomez Williams    Ronald Davis        2023-12-06
# 50377        Pollard Wallace, Sims and  James Bass Phd        2020-12-30
# 53590                   Davis-Lawrence   Jessica Chung        2020-07-06
# 52172  Arellano and Armstrong Hensley,  Charles Jordan        2021-05-13
#
#       Discharge Date  Age  Gender Blood Type Medical Condition  \
# 51900     2020-03-20   13  Female         A+           Obesity
# 50908     2024-01-04   13    Male         A+           Obesity
# 50377     2021-01-17   13    Male         O+            Asthma
# 53590     2020-07-11   13    Male        AB+           Obesity
# 52172     2021-06-12   13    Male         A+         Arthritis
#
#                  Doctor Insurance Provider  Billing Amount  Room Number  \
# ...

# %%
df2.dtypes
# Out:
# Hospital               object
# Name                   object
# Date of Admission      object
# Discharge Date         object
# Age                     int64
# Gender                 object
# Blood Type             object
# Medical Condition      object
# Doctor                 object
# Insurance Provider     object
# Billing Amount        float64
# Room Number             int64
# Admission Type         object
# Medication             object
# Test Results           object
# dtype: object

# %%
df2['Date of Admission'] = pd.to_datetime(df2['Date of Admission'])
df2['Discharge Date'] = pd.to_datetime(df2['Discharge Date'])

# %%
df2.dtypes
# Out:
# Hospital                      object
# Name                          object
# Date of Admission     datetime64[ns]
# Discharge Date        datetime64[ns]
# Age                            int64
# Gender                        object
# Blood Type                    object
# Medical Condition             object
# Doctor                        object
# Insurance Provider            object
# Billing Amount               float64
# Room Number                    int64
# Admission Type                object
# Medication                    object
# Test Results                  object
# dtype: object

# %%
df2['spent_day'] = df2['Discharge Date'] - df2['Date of Admission']

# %%
df2.head()
# Out:
#                               Hospital            Name Date of Admission  \
# 51900            and Huerta, Cox Price  Jacob Williams        2020-03-03
# 50908        Kelly, and Gomez Williams    Ronald Davis        2023-12-06
# 50377        Pollard Wallace, Sims and  James Bass Phd        2020-12-30
# 53590                   Davis-Lawrence   Jessica Chung        2020-07-06
# 52172  Arellano and Armstrong Hensley,  Charles Jordan        2021-05-13
#
#       Discharge Date  Age  Gender Blood Type Medical Condition  \
# 51900     2020-03-20   13  Female         A+           Obesity
# 50908     2024-01-04   13    Male         A+           Obesity
# 50377     2021-01-17   13    Male         O+            Asthma
# 53590     2020-07-11   13    Male        AB+           Obesity
# 52172     2021-06-12   13    Male         A+         Arthritis
#
#                  Doctor Insurance Provider  Billing Amount  Room Number  \
# ...

# %%
a = df2.sort_values(by = 'Billing Amount', ascending = False)
a.head()
# Out:
#                Hospital              Name Date of Admission Discharge Date  \
# 36349     Griffin Group     Todd Carrillo        2023-09-08     2023-10-04
# 34613  Hernandez-Morton       Karen Kline        2021-06-19     2021-07-03
# 51313  Hernandez-Morton       Karen Kline        2021-06-19     2021-07-03
# 5735    Sons and Bailey    David Sandoval        2019-11-02     2019-11-11
# 7088         Miller Ltd  Kathryn Gonzales        2020-08-11     2020-08-12
#
#        Age  Gender Blood Type Medical Condition             Doctor  \
# 36349   51  Female         A+      Hypertension   Kathleen Griffin
# 34613   79  Female        AB+            Cancer  Dr. Joseph Gordon
# 51313   74  Female        AB+            Cancer  Dr. Joseph Gordon
# 5735    22    Male        AB-      Hypertension       Taylor Novak
# 7088    18  Female         O+          Diabetes      Kristin Clark
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# ...

# %%
cols = ['Date of Admission','Hospital','Billing Amount']
grouped = df2.groupby(cols, as_index = False)['Billing Amount']
result = grouped.sum()
result
# Out:
#       Date of Admission                     Hospital  Billing Amount
# 0            2019-05-08    Allen, Quinn Mitchell and     4360.795861
# 1            2019-05-08               Bailey-Freeman    12536.753390
# 2            2019-05-08                Bailey-Herman     9379.010120
# 3            2019-05-08        Baker and Boyd, Floyd    25621.998595
# 4            2019-05-08  Chandler, and Olson Holland    20520.280587
# ...                 ...                          ...             ...
# 49995        2024-05-07               Sparks-Hawkins    92619.952371
# 49996        2024-05-07             Wright-Dougherty    14133.936362
# 49997        2024-05-07   and Dawson, Payne Phillips    12653.158803
# 49998        2024-05-07         and Rowe Wood Reyes,    46204.642438
# 49999        2024-05-07           and Sons Rodriguez    10093.235691
#
# [50000 rows x 3 columns]

# %%
con1 = df2['Date of Admission'] == '2020-03-03'
con2 = df2['Hospital'] == 'and Huerta, Cox Price'
filt = df2.loc[con1 & con2]
filt
# Out:
#                     Hospital            Name Date of Admission Discharge Date  \
# 51900  and Huerta, Cox Price  Jacob Williams        2020-03-03     2020-03-20
# 6321   and Huerta, Cox Price  Jacob Williams        2020-03-03     2020-03-20
#
#        Age  Gender Blood Type Medical Condition          Doctor  \
# 51900   13  Female         A+           Obesity  Samantha Scott
# 6321    18  Female         A+           Obesity  Samantha Scott
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# 51900           Medicare    42349.109219          373         Urgent
# 6321            Medicare    42349.109219          373         Urgent
#
#       Medication Test Results spent_day
# 51900  Ibuprofen       Normal   17 days
# 6321   Ibuprofen       Normal   17 days

# %%
df2.head()
# Out:
#                               Hospital            Name Date of Admission  \
# 51900            and Huerta, Cox Price  Jacob Williams        2020-03-03
# 50908        Kelly, and Gomez Williams    Ronald Davis        2023-12-06
# 50377        Pollard Wallace, Sims and  James Bass Phd        2020-12-30
# 53590                   Davis-Lawrence   Jessica Chung        2020-07-06
# 52172  Arellano and Armstrong Hensley,  Charles Jordan        2021-05-13
#
#       Discharge Date  Age  Gender Blood Type Medical Condition  \
# 51900     2020-03-20   13  Female         A+           Obesity
# 50908     2024-01-04   13    Male         A+           Obesity
# 50377     2021-01-17   13    Male         O+            Asthma
# 53590     2020-07-11   13    Male        AB+           Obesity
# 52172     2021-06-12   13    Male         A+         Arthritis
#
#                  Doctor Insurance Provider  Billing Amount  Room Number  \
# ...

# %%
a = df2['Billing Amount'] <10000
b = df2[a]
b.head()
# Out:
#                          Hospital             Name Date of Admission  \
# 50908   Kelly, and Gomez Williams     Ronald Davis        2023-12-06
# 55227  and Spencer Johnson Lewis,          Jim Day        2021-06-20
# 51203                  Lamb-Mills  Brenda Berry Md        2020-07-14
# 52703            Stewart-Stephens     Maria Becker        2023-03-03
# 54494                Group Howard       David Shaw        2019-10-26
#
#       Discharge Date  Age  Gender Blood Type Medical Condition  \
# 50908     2024-01-04   13    Male         A+           Obesity
# 55227     2021-06-28   14    Male         O-         Arthritis
# 51203     2020-08-04   14  Female        AB+           Obesity
# 52703     2023-03-14   14    Male        AB+           Obesity
# 54494     2019-11-22   14  Female         A+            Cancer
#
#                  Doctor Insurance Provider  Billing Amount  Room Number  \
# 50908    Shannon Butler              Cigna     3014.565852          241
# ...

# %%
col = ['Hospital','Doctor']
grp = df2.groupby(col)['Doctor']
res = grp.count()
res
# Out:
# Hospital                       Doctor
# Abbott Inc                     Brandi Lucas         1
# Abbott Ltd                     Jessica Arnold       1
# Abbott Moore and Williams,     Jordan Black         1
# Abbott and Thompson, Sullivan  Angela Hernandez     1
# Abbott, Peters and Hoffman     Kelsey Logan         2
#                                                    ..
# and Zimmerman Sons             Catherine Howell     1
# and Zuniga Davis Carlson,      Philip Montgomery    1
# and Zuniga Francis Peterson,   Jane Gomez           1
# and Zuniga Sons                Taylor Floyd         1
# and Zuniga Thompson, Blake     Sean Curry           1
# Name: Doctor, Length: 50000, dtype: int64

# %%
df2.head()
# Out:
#                               Hospital            Name Date of Admission  \
# 51900            and Huerta, Cox Price  Jacob Williams        2020-03-03
# 50908        Kelly, and Gomez Williams    Ronald Davis        2023-12-06
# 50377        Pollard Wallace, Sims and  James Bass Phd        2020-12-30
# 53590                   Davis-Lawrence   Jessica Chung        2020-07-06
# 52172  Arellano and Armstrong Hensley,  Charles Jordan        2021-05-13
#
#       Discharge Date  Age  Gender Blood Type Medical Condition  \
# 51900     2020-03-20   13  Female         A+           Obesity
# 50908     2024-01-04   13    Male         A+           Obesity
# 50377     2021-01-17   13    Male         O+            Asthma
# 53590     2020-07-11   13    Male        AB+           Obesity
# 52172     2021-06-12   13    Male         A+         Arthritis
#
#                  Doctor Insurance Provider  Billing Amount  Room Number  \
# ...

# %%
a = df2['Hospital'] == 'Kelly, and Gomez Williams'
b = df2['Doctor'] == 'Shannon Butler'
fil = df2.loc[a & b]
fil
# Out:
#                         Hospital          Name Date of Admission  \
# 50908  Kelly, and Gomez Williams  Ronald Davis        2023-12-06
# 40889  Kelly, and Gomez Williams  Ronald Davis        2023-12-06
#
#       Discharge Date  Age Gender Blood Type Medical Condition          Doctor  \
# 50908     2024-01-04   13   Male         A+           Obesity  Shannon Butler
# 40889     2024-01-04   18   Male         A+           Obesity  Shannon Butler
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# 50908              Cigna     3014.565852          241      Emergency
# 40889              Cigna     3014.565852          241      Emergency
#
#         Medication Test Results spent_day
# 50908  Paracetamol       Normal   29 days
# 40889  Paracetamol       Normal   29 days

# %%
a = df2['Hospital'] == 'Kelly, and Gomez Williams'
b = df2[a]
b
# Out:
#                         Hospital          Name Date of Admission  \
# 50908  Kelly, and Gomez Williams  Ronald Davis        2023-12-06
# 40889  Kelly, and Gomez Williams  Ronald Davis        2023-12-06
#
#       Discharge Date  Age Gender Blood Type Medical Condition          Doctor  \
# 50908     2024-01-04   13   Male         A+           Obesity  Shannon Butler
# 40889     2024-01-04   18   Male         A+           Obesity  Shannon Butler
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# 50908              Cigna     3014.565852          241      Emergency
# 40889              Cigna     3014.565852          241      Emergency
#
#         Medication Test Results spent_day
# 50908  Paracetamol       Normal   29 days
# 40889  Paracetamol       Normal   29 days
